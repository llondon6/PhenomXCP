# %%
# Setup ipython environment
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Setup the notebook's environment
import lalsimulation as lalsim
from matplotlib.pyplot import *
from numpy import *
from positive import *
from nrutils import scsearch, gwylm
# Out:
# (positive)>> Applying custom matplotlib settings.

# %%
a = scsearch(keyword='q8a08t30',verbose=True)
# Out:
# (scsearch)>> Found keyword (=q8a08t30) keyword.
# (scsearch)>> Found verbose (=True) keyword.
# (scsearch)>> List of keywords or string keyword found: ALL scentry objects matching will be passed. To pass ANY entries matching the keywords, input the keywords using an iterable of not of type list.
# (scsearch)>> ## Found 7 possibly degenerate simulations:
# (scsearch)>> [0001][pnr-catalog] q8: 1chi0.80-p-q8.00	(q8a08t30dPm9.35_r0.5_T_96_360)
# (scsearch)>> [0002][hogshead] q8precessing: 1chi0.80-p-q8.00	(q8a08t30dPm9.35_r0.5_T_96_360)
# (scsearch)>> [0003][hogshead] eccentricity_reduction: 1chi0.80-p-q8.00	(q8a08t30dPm9D_T_80_320)
# (scsearch)>> [0004][hogshead] eccentricity_reduction: 1chi0.80-p-q8.00	(q8a08t30dPm12D_T_80_320)
# (scsearch)>> [0005][hogshead] eccentricity_reduction: 1chi0.80-p-q8.00	(q8a08t30dPm9.5D_T_80_320)
# (scsearch)>> [0006][hogshead] eccentricity_reduction: 1chi0.80-p-q8.00	(q8a08t30dPm6D_T_80_320)
# ...

# %%
y = gwylm(a[0],lm=[(2,2)],clean=True,verbose=True,load_dynamics=True)
# Out:
# (gwylm)>> Found clean (=True) keyword.
# (gwylm)>> Found dt (=0.15) keyword.
# (gwylm)>> Found enforce_m_relative_sign_convention (=True) keyword.
# (gwylm)>> Found inf (=inf) keyword.
# (gwylm)>> Found lm (=[(2, 2)]) keyword.
# (gwylm)>> Found load_dynamics (=True) keyword.
# (gwylm)>> Found scentry_obj (=<nrutils.core.nrsc.scentry object at 0xa19b555c0>) keyword.
# (gwylm)>> Found verbose (=True) keyword.
# (__init__)>> Using default M_RELATIVE_SIGN_CONVENTION of 1
# (gwylm)>> The (extraction_parameter,level) is (5,7), which differs from the config values of (5,5). You have either manually input the non-config values, or the handler has set them by looking at the contents of the simulation directory.
# (__make_lmlist__)>> The following spherical multipoles will be loaded:[(2, 2)]
# (load)>> Using the default extraction_parameter of 5
# (load)>> Loading: psi3col.r5.l7.l2.m2.gz
# (load)>> Imposing a default padding of 4 to the data.
# ...

# %%
fig = figure( figsize=1.2*4*figaspect(1) )
ax = fig.add_subplot(111,projection='3d')

plot_3d_mesh_sphere( ax, color='k', alpha=0.05, lw=1 )
y.plot_3d_J(ax=ax)
y.plot_3d_S(ax=ax,color='g')
y.plot_3d_trajectory(ax=ax, legend_on=True)


# ax.view_init(45,45)
# Out:
# <Axes3DSubplot:>
# /Users/book/opt/anaconda2/envs/hack-phenomx3/lib/python3.6/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
